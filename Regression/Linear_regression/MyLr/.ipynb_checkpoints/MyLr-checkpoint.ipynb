# %% [markdown]
# ## Simple Liner Regression

# %%
class MyLr:
    def __init__(self):
        self.m = None
        self.b = None
        
    def fit(self, x_train, y_train): 
        self.m = sum( (x_train - x_train.mean()) * (y_train - y_train.mean())  ) / sum((x_train - x_train.mean()) ** 2  )
        self.b = y_train.mean() - self.m * x_train.mean()
        print("coefficient", self.m)
        print("intercept", self.b)
        
    def predict(self, x_test):
        return self.m * x_test + self.b

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("datasets/advertising.csv")
df = data[["TV","Sales"]]
df
# Out:
#         TV  Sales
# 0    230.1   22.1
# 1     44.5   10.4
# 2     17.2   12.0
# 3    151.5   16.5
# 4    180.8   17.9
# ..     ...    ...
# 195   38.2    7.6
# 196   94.2   14.0
# 197  177.0   14.8
# 198  283.6   25.5
# 199  232.1   18.4
#
# [200 rows x 2 columns]

# %%
x = df["TV"].values
y = df["Sales"].values
x
y.shape
# Out:
# (200,)

# %% [markdown]
# ### spliting data for train and test

# %%
from sklearn.model_selection import train_test_split
x_train , x_test, y_train ,y_test = train_test_split(x,y , test_size = 0.2)

# %%
x_train.shape
# Out:
# (160,)

# %% [markdown]
# ### Training model

# %%
lr = MyLr()

# %%
lr.fit(x_train, y_train)
# Out:
# coefficient 0.05475962312734338
# intercept 7.066814427197075

# %%
lr.predict(x_test[34])
# Out:
# np.float64(16.75926772073685)

# %% [markdown]
# ### Best fit line

# %%
y_pred = lr.predict(x_train)

# %%
plt.scatter(x, y)
plt.plot(x_train, y_pred, color = "black")
plt.xlabel("TV")
plt.ylabel("Sales")
# Out:
# Text(0, 0.5, 'Sales')

# %% [markdown]
# ### calculating efficiency

# %%
from sklearn.metrics import r2_score

# %%
r2 = r2_score(y_train, y_pred)
r2
# Out:
# 0.8041015151476925

# %% [markdown]
# #### my model is 80 percent accurate
